# %%
# This notebook gathers metadata for the MERFISH dataset. 
# In particular we want to get (x,y,z) co-ordinates, and celltype annotations for the MERFISH and Zhuang datasets. 
import anndata as ad
import pandas as pd
import numpy as np
import toml

# %%
paths = toml.load('/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/abcex/config.toml')['root']
expr_data = ad.read_h5ad(paths['data']+'expression_matrices/MERFISH-C57BL6J-638850/20230830/C57BL6J-638850-log2.h5ad', backed='r')
expr_data_raw = ad.read_h5ad(paths['data']+'expression_matrices/MERFISH-C57BL6J-638850/20230830/C57BL6J-638850-raw.h5ad', backed='r')

# %%
expr_data.var[501:]
# Out:
#                 gene_symbol transcript_identifier
# gene_identifier
# Blank-49           Blank-49              Blank-49
# Blank-43           Blank-43              Blank-43
# Blank-25           Blank-25              Blank-25
# Blank-12           Blank-12              Blank-12
# Blank-20           Blank-20              Blank-20
# Blank-1             Blank-1               Blank-1
# Blank-3             Blank-3               Blank-3
# Blank-5             Blank-5               Blank-5
# Blank-6             Blank-6               Blank-6
# Blank-7             Blank-7               Blank-7
# Blank-14           Blank-14              Blank-14
# Blank-21           Blank-21              Blank-21
# Blank-24           Blank-24              Blank-24
# Blank-26           Blank-26              Blank-26
# Blank-27           Blank-27              Blank-27
# Blank-29           Blank-29              Blank-29
# Blank-30           Blank-30              Blank-30
# Blank-31           Blank-31              Blank-31
# Blank-35           Blank-35              Blank-35
# Blank-37           Blank-37              Blank-37
# Blank-39           Blank-39              Blank-39
# Blank-40           Blank-40              Blank-40
# Blank-41           Blank-41              Blank-41
# Blank-42           Blank-42              Blank-42
# Blank-44           Blank-44              Blank-44
# Blank-46           Blank-46              Blank-46
# Blank-47           Blank-47              Blank-47
# Blank-50           Blank-50              Blank-50
# Blank-2             Blank-2               Blank-2
# Blank-8             Blank-8               Blank-8
# Blank-9             Blank-9               Blank-9
# Blank-10           Blank-10              Blank-10
# Blank-13           Blank-13              Blank-13
# Blank-15           Blank-15              Blank-15
# Blank-17           Blank-17              Blank-17
# Blank-19           Blank-19              Blank-19
# Blank-22           Blank-22              Blank-22
# Blank-38           Blank-38              Blank-38
# Blank-11           Blank-11              Blank-11
# Blank-16           Blank-16              Blank-16
# Blank-32           Blank-32              Blank-32
# Blank-18           Blank-18              Blank-18
# Blank-4             Blank-4               Blank-4
# Blank-28           Blank-28              Blank-28
# Blank-33           Blank-33              Blank-33
# Blank-34           Blank-34              Blank-34
# Blank-45           Blank-45              Blank-45
# Blank-23           Blank-23              Blank-23
# Blank-48           Blank-48              Blank-48

# %%
x = expr_data_raw.X[:,0:500].toarray()
np.mean(np.sum(x, axis=1))

# %%
x_log2 = expr_data.X[0,0:500].toarray().squeeze()
x_raw = expr_data_raw.X[0,0:500].toarray().squeeze()

# %%
x_raw.shape
# Out:
# (500,)

# %%
import matplotlib.pyplot as plt

cpm_factor = 800/np.sum(x_raw)
x_ = np.log2(x_raw * cpm_factor + 1)

plt.scatter(x_, x_log2, s=1)
plt.plot([0,10], [0,10], '-')

# %%
x_raw

# %%
x_log2[0:10]
# Out:
# array([0.        , 0.        , 0.        , 2.27356674, 0.        ,
#        0.        , 0.        , 0.        , 1.54477479, 0.        ])

# %%
genes_anno = pd.read_csv(paths['data']+'metadata/MERFISH-C57BL6J-638850/20230830/gene.csv')
cells_anno_1 = pd.read_csv(paths['data']+'metadata/MERFISH-C57BL6J-638850/20230830/cell_metadata.csv')
cells_anno_2 = pd.read_csv(paths['data']+'metadata/MERFISH-C57BL6J-638850/20230830/views/cell_metadata_with_cluster_annotation.csv')
cells_anno_3 = pd.read_csv(paths['data']+'metadata/MERFISH-C57BL6J-638850/20230830/views/ccf_coords.csv')
# ccf_coords.csv was generated using 01_merfish_ccf_registration_tutorial.ipynb adapted from abc_atlas_access/notebooks.

# %%
print(genes_anno.columns)
print(cells_anno_1.columns)
print(cells_anno_2.columns)
print(cells_anno_3.columns)
# Out:
# Index(['gene_identifier', 'gene_symbol', 'transcript_identifier', 'name',
#        'mapped_ncbi_identifier'],
#       dtype='object')
# Index(['cell_label', 'brain_section_label', 'cluster_alias',
#        'average_correlation_score', 'feature_matrix_label', 'donor_label',
#        'donor_genotype', 'donor_sex', 'x', 'y', 'z'],
#       dtype='object')
# Index(['cell_label', 'brain_section_label', 'cluster_alias',
#        'average_correlation_score', 'feature_matrix_label', 'donor_label',
#        'donor_genotype', 'donor_sex', 'x', 'y', 'z', 'neurotransmitter',
#        'class', 'subclass', 'supertype', 'cluster', 'neurotransmitter_color',
#        'class_color', 'subclass_color', 'supertype_color', 'cluster_color'],
#       dtype='object')
# Index(['cell_label', 'brain_section_label', 'cluster_alias',
#        'average_correlation_score', 'feature_matrix_label', 'donor_label',
#        'donor_genotype', 'donor_sex', 'x_section', 'y_section', 'z_section',
#        'neurotransmitter', 'class', 'subclass', 'supertype', 'cluster',
#        'neurotransmitter_color', 'class_color', 'subclass_color',
#        'supertype_color', 'cluster_color', 'x_reconstructed',
#        'y_reconstructed', 'z_reconstructed', 'parcellation_index', 'x_ccf',
#        'y_ccf', 'z_ccf', 'parcellation_organ', 'parcellation_category',
#        'parcellation_division', 'parcellation_structure',
#        'parcellation_substructure', 'parcellation_organ_color',
#        'parcellation_category_color', 'parcellation_division_color',
#        'parcellation_structure_color', 'parcellation_substructure_color'],
#       dtype='object')

# %%
expr_data_ = expr_data[cells_anno_3['cell_label'],:]

# %%
print(expr_data.shape)
print(cells_anno_1.shape)
print(cells_anno_2.shape)
print('---')
print(expr_data_.shape)
print(cells_anno_3.shape)
# Out:
# (4334174, 550)
# (3938808, 11)
# (3938808, 21)
# ---
# (3739961, 550)
# (3739961, 38)

# %%
assert np.all(cells_anno_1['cell_label']==cells_anno_2['cell_label'])
assert np.all(expr_data_.obs.index==cells_anno_3['cell_label'])
display(cells_anno_3['parcellation_division'].value_counts().to_frame())
# Out:
#                           count
# parcellation_division
# Isocortex                935742
# STR                      401346
# CB                       383127
# HPF                      304642
# MB                       281852
# OLF                      274354
# MY                       147562
# P                        136569
# TH                       133805
# HY                       132902
# lfbs                     104430
# PAL                       77885
# unassigned                68586
# cm                        63678
# CTXsp                     60747
# cbf                       60456
# mfbs                      55894
# VL                        35475
# scwm                      18473
# brain-unassigned          17945
# V3                        12322
# fiber tracts-unassigned   12317
# V4                        11736
# eps                        5206
# AQ                         2910

# %%
# The Zhuang dataset seems to have a separate annotation for ccf coordinates.
display(cells_anno_3['parcellation_organ'].value_counts().to_frame())
display(cells_anno_3['parcellation_structure'].value_counts().to_frame())
# Out:
#                       count
# parcellation_organ
# brain               3671375
# unassigned            68586
#                          count
# parcellation_structure
# CP                      234174
# MOs                      90859
# MOp                      83976
# PIR                      77916
# MOB                      77675
# ...                        ...
# ISN                         45
# IV                          36
# ACVII                       36
# BA                          25
# Xn                          16
#
# [354 rows x 1 columns]

# %%
parc = ['parcellation_organ', 'parcellation_category',
       'parcellation_division', 'parcellation_structure',
       'parcellation_substructure']

df = cells_anno_3[parc].drop_duplicates()
display(df)
# Out:
#         parcellation_organ parcellation_category parcellation_division  \
# 0                    brain                  grey                   HPF
# 1                    brain                  grey                     P
# 2                    brain                  grey                     P
# 3                    brain          fiber tracts                   cbf
# 7                    brain                  grey                     P
# ...                    ...                   ...                   ...
# 743025               brain                  grey                    MB
# 910693               brain                  grey                    MB
# 932528               brain          fiber tracts                    cm
# 958180               brain                  grey             Isocortex
# 1101541              brain                  grey             Isocortex
#
#         parcellation_structure parcellation_substructure
# 0                           DG                     DG-po
# 1                          TRN                       TRN
# 2                 P-unassigned              P-unassigned
# 3                          arb                       arb
# 7                           PG                        PG
# ...                        ...                       ...
# 743025                      IV                        IV
# 910693                     IPN            IPN-unassigned
# 932528                      Xn                        ts
# 958180                     FRP                     FRP6b
# 1101541                    AIv                     AIv6b
#
# [670 rows x 5 columns]

# %%
meta = cells_anno_3

# %%
expr_data_ = expr_data[meta['cell_label'],:]
print(expr_data_.shape)
# Out:
# (3739961, 550)

# %%
assert np.all(meta["cell_label"]==expr_data_.obs.index), "metadata and expression are not the same"

# %%
#display(meta['parcellation_structure'].value_counts().to_frame())

# %%
display(meta['z_section'].value_counts().to_frame().reset_index().sort_values('z_section').reset_index(drop=True))
# Out:
#     z_section   count
# 0         0.8   45915
# 1         1.0   46526
# 2         1.4   47009
# 3         1.6   69235
# 4         1.8   42098
# 5         2.0   47690
# 6         2.2   50612
# 7         2.4   71231
# 8         2.6   94385
# 9         2.8   80333
# 10        3.0   80453
# 11        3.2   58893
# 12        3.4   44338
# 13        3.6   61618
# 14        3.8   61621
# 15        4.0   73779
# 16        4.2   79307
# 17        4.4   49921
# 18        4.6   79139
# 19        4.8   77777
# 20        5.0   91051
# 21        5.4   91988
# 22        5.6   93489
# 23        5.8   77424
# 24        6.2   87448
# 25        6.4  115779
# 26        6.6   90145
# 27        6.8  120186
# 28        7.0   69170
# 29        7.2  104572
# 30        7.6   67500
# 31        7.8   99806
# 32        8.0  112169
# 33        8.2  105415
# 34        8.4   98702
# 35        8.8   80731
# 36        9.0   71250
# 37        9.2   98736
# 38        9.4   92826
# 39        9.6   98934
# 40        9.8   93231
# 41       10.2   85573
# 42       10.4   63929
# 43       10.8   57175
# 44       11.0   51981
# 45       11.2   44699
# 46       11.4   37482
# 47       11.8   33435
# 48       12.0   32395
# 49       12.2   33134
# 50       13.0   22273
# 51       13.8   26209
# 52       14.2   29244

# %%
meta_ = meta.loc[(meta['z_section'].round(1)==6.8)].copy()
expr_data_ = expr_data[meta_['cell_label'],:]
meta_.reset_index(drop=True, inplace=True)

# %%
meta_.columns
# Out:
# Index(['cell_label', 'brain_section_label', 'cluster_alias',
#        'average_correlation_score', 'feature_matrix_label', 'donor_label',
#        'donor_genotype', 'donor_sex', 'x_section', 'y_section', 'z_section',
#        'neurotransmitter', 'class', 'subclass', 'supertype', 'cluster',
#        'neurotransmitter_color', 'class_color', 'subclass_color',
#        'supertype_color', 'cluster_color', 'x_reconstructed',
#        'y_reconstructed', 'z_reconstructed', 'parcellation_index', 'x_ccf',
#        'y_ccf', 'z_ccf', 'parcellation_organ', 'parcellation_category',
#        'parcellation_division', 'parcellation_structure',
#        'parcellation_substructure', 'parcellation_organ_color',
#        'parcellation_category_color', 'parcellation_division_color',
#        'parcellation_structure_color', 'parcellation_substructure_color'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns


custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", font_scale=0.8, rc=custom_params)
# %config InlineBackend.figure_format="retina"

# %%
print(meta_["parcellation_substructure"].unique().shape)
print(meta_["parcellation_division"].unique().shape)
display(meta_["parcellation_division"].value_counts().to_frame())
# Out:
# (201,)
# (18,)
#                          count
# parcellation_division
# Isocortex                35438
# TH                       19644
# HY                       13244
# HPF                      10398
# STR                       9318
# lfbs                      8821
# CTXsp                     5692
# OLF                       5162
# mfbs                      4476
# PAL                       1874
# scwm                      1330
# fiber tracts-unassigned   1271
# VL                         874
# cm                         778
# unassigned                 655
# brain-unassigned           612
# V3                         484
# eps                        115

# %%
print(meta_["subclass"].unique().shape)
f, ax = plt.subplots(1,2,figsize=(5,2))
ax[0].plot(np.sort(meta_["subclass"].value_counts().to_frame()["count"].values)[::-1]/meta_.shape[0])
ax[0].set(xlabel="sorted subclasses", ylabel="fraction of cells", ylim=(0,0.1))

ax[1].plot(np.sort(meta_["subclass"].value_counts().to_frame()["count"].values)[::-1], c="r")
ax[1].set(xlabel="sorted subclasses", ylabel="number of cells", ylim=(0,2500))

plt.tight_layout()
plt.show()
# Out:
# (164,)

# %%
# subset just for quick plotting
ind = np.random.choice(a=meta_.shape[0], size=5000, replace=False)

f, ax = plt.subplots(1,1,figsize=(3,3))
ax.scatter(meta_["x_section"].iloc[ind], meta_["y_section"].iloc[ind], s=1, c=meta_["parcellation_division_color"].iloc[ind])
ax.axis("equal")
ax.invert_yaxis()

# %%
save_path = "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/abcex/data/"
adata = expr_data_.to_memory()

# %%
adata.obs = meta_
adata.write_h5ad(save_path+"test_one_section.h5ad")
